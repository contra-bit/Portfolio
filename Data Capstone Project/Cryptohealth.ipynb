# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
# %matplotlib inline

# %%
start = datetime.date(2008, 1, 1)
end =  datetime.date(2018 ,1 , 1)
cstart= '1-1-2010'
cend = '1-1-2018'

# %%
from cryptocmd import CmcScraper

# Bitcoin
# initialise scraper
BTCscraper = CmcScraper('BTC', cstart, cend)
# Pandas dataFrame for the same data
BTC = BTCscraper.get_dataframe()

# Ethereum
# initialise scraper
ETHscraper = CmcScraper('ETH', cstart, cend)
# Pandas dataFrame for the same data
ETH = ETHscraper.get_dataframe()

# Ripple
# initialise scraper
XRPscraper = CmcScraper('XRP', cstart, cend)
# Pandas dataFrame for the same data
XRP = XRPscraper.get_dataframe()

# Bitcoin Classic
# initialise scraper
BCHscraper = CmcScraper('BCH', cstart, cend)
# Pandas dataFrame for the same data
BCH = BCHscraper.get_dataframe()

# Cardano
# initialise scraper
ADAscraper = CmcScraper('ADA', cstart, cend)
# Pandas dataFrame for the same data
ADA = scraper.get_dataframe()

# Litecoin 
# initialise scraper
LTCscraper = CmcScraper('LTC', cstart, cend)
# Pandas dataFrame for the same data
LTC = scraper.get_dataframe()

# Neo 
# initialise scraper
NEOscraper = CmcScraper('NEO', cstart, cend)
# Pandas dataFrame for the same data
NEO = scraper.get_dataframe()

# Stellar
# initialise scraper
XLMscraper = CmcScraper('XLM', cstart, cend)
# Pandas dataFrame for the same data
XLM = scraper.get_dataframe()

# EOS
# initialise scraper
EOSscraper = CmcScraper('EOS', cstart, cend)
# Pandas dataFrame for the same data
EOS = scraper.get_dataframe()

# IOTA
# initialise scraper
MIOTAscraper = CmcScraper('MIOTA', cstart, cend)
# Pandas dataFrame for the same data
MIOTA = scraper.get_dataframe()

# DASH
# initialise scraper
DASHscraper = CmcScraper('DASH', cstart, cend)
# Pandas dataFrame for the same data
DASH = scraper.get_dataframe()

# XMR
# initialise scraper
XMRscraper = CmcScraper('XMR', cstart, cend)
# Pandas dataFrame for the same data
XMR = scraper.get_dataframe()

# Ethereum Classic
# initialise scraper
ETCscraper = CmcScraper('ETC', cstart, cend)
# Pandas dataFrame for the same data
ETC = scraper.get_dataframe()

# Zcash
# initialise scraper
ZECscraper = CmcScraper('ZEC', cstart, cend)
# Pandas dataFrame for the same data
ZEC = scraper.get_dataframe()

# %% [markdown]
# ** Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers**

# %%
tickers = ['BTC', 'ETH', 'XRP', 'BCH', 'ADA', 'LTC', 'NEO', 'XLM', 'EOS', 'MIOTA', 'DASH', 'XMR', 'ETC', 'ZEC']

# %% [markdown]
# ** Use pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks. Set the keys argument equal to the tickers list. Also pay attention to what axis you concatenate on.**

# %%
crypto_stocks = pd.concat([BTC, ETH, XRP, BCH, ADA, LTC, NEO, XLM, EOS, MIOTA, DASH, XMR, ETC, ZEC], axis=1, keys=tickers)

# %%
crypto_stocks.columns.names = ['Currency Ticker', 'Stock Info'] #Sets Columns Name

# %%
crypto_stocks.head()
# Out:
# Currency Ticker        BTC                                                   \
# Stock Info            Date     Open     High      Low    Close       Volume
# 0               2018-01-01  14112.2  14112.2  13154.7  13657.2  10291200000
# 1               2017-12-31  12897.7  14377.4  12755.6  14156.4  12136300000
# 2               2017-12-30  14681.9  14681.9  12350.1  12952.2  14452600000
# 3               2017-12-29  14695.8  15279.0  14307.0  14656.2  13025500000
# 4               2017-12-28  15864.1  15888.4  13937.3  14606.5  12336500000
#
# Currency Ticker                      ETH                      ...       \
# Stock Info         Market Cap       Date    Open    High      ...
# 0                236725000000 2018-01-01  755.76  782.53      ...
# 1                216326000000 2017-12-31  712.21  760.35      ...
# 2                246224000000 2017-12-30  753.82  753.82      ...
# 3                246428000000 2017-12-29  740.39  770.12      ...
# 4                265988000000 2017-12-28  762.21  763.32      ...
#
# Currency Ticker      ETC                                   ZEC           \
# Stock Info         Close       Volume    Market Cap       Date     Open
# 0                13657.2  10291200000  236725000000 2018-01-01  14112.2
# 1                14156.4  12136300000  216326000000 2017-12-31  12897.7
# 2                12952.2  14452600000  246224000000 2017-12-30  14681.9
# 3                14656.2  13025500000  246428000000 2017-12-29  14695.8
# 4                14606.5  12336500000  265988000000 2017-12-28  15864.1
#
# Currency Ticker
# Stock Info          High      Low    Close       Volume    Market Cap
# 0                14112.2  13154.7  13657.2  10291200000  236725000000
# 1                14377.4  12755.6  14156.4  12136300000  216326000000
# 2                14681.9  12350.1  12952.2  14452600000  246224000000
# 3                15279.0  14307.0  14656.2  13025500000  246428000000
# 4                15888.4  13937.3  14606.5  12336500000  265988000000
#
# [5 rows x 98 columns]

# %%
crypto_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Currency Ticker
# BTC      19497.40
# ETH        826.82
# XRP          2.39
# BCH       3923.07
# ADA      19497.40
# LTC      19497.40
# NEO      19497.40
# XLM      19497.40
# EOS      19497.40
# MIOTA    19497.40
# DASH     19497.40
# XMR      19497.40
# ETC      19497.40
# ZEC      19497.40
# dtype: float64

# %% [markdown]
# ** Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick+' Return'] = crypto_stocks[tick]['Close'].pct_change()
returns.head()
# Out:
#    BTC Return  ETH Return  XRP Return  BCH Return  ADA Return  LTC Return  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1    0.036552   -0.020592   -0.037657    0.041303    0.036552    0.036552
# 2   -0.085064   -0.052159   -0.060870   -0.055507   -0.085064   -0.085064
# 3    0.131561    0.050651    0.023148    0.161987    0.131561    0.131561
# 4   -0.003391   -0.021988   -0.352941   -0.076732   -0.003391   -0.003391
#
#    NEO Return  XLM Return  EOS Return  MIOTA Return  DASH Return  XMR Return  \
# 0         NaN         NaN         NaN           NaN          NaN         NaN
# 1    0.036552    0.036552    0.036552      0.036552     0.036552    0.036552
# 2   -0.085064   -0.085064   -0.085064     -0.085064    -0.085064   -0.085064
# 3    0.131561    0.131561    0.131561      0.131561     0.131561    0.131561
# 4   -0.003391   -0.003391   -0.003391     -0.003391    -0.003391   -0.003391
#
#    ETC Return  ZEC Return
# 0         NaN         NaN
# 1    0.036552    0.036552
# 2   -0.085064   -0.085064
# 3    0.131561    0.131561
# 4   -0.003391   -0.003391

# %%
sns.pairplot(returns[1:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-d8fc120e1ef5> in <module>()
# ----> 1 sns.pairplot(returns[1:])
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    2036     if grid.square_grid:
#    2037         if diag_kind == "hist":
# -> 2038             grid.map_diag(plt.hist, **diag_kws)
#    2039         elif diag_kind == "kde":
#    2040             diag_kws["legend"] = False
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1352                 else:
#    1353                     func(vals, color=color, histtype="barstacked",
# -> 1354                          **kwargs)
#    1355             else:
#    1356                 for k, label_k in enumerate(self.hue_names):
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3002                       histtype=histtype, align=align, orientation=orientation,
#    3003                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3004                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3005     finally:
#    3006         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist(***failed resolving arguments***)
#    6205             # this will automatically overwrite bins,
#    6206             # so that each histogram uses the same bins
# -> 6207             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6208             m = m.astype(float)  # causes problems later if it's an int
#    6209             if mlast is None:
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in histogram(a, bins, range, normed, weights, density)
#     665     if mn > mx:
#     666         raise ValueError(
# --> 667             'max must be larger than min in range parameter.')
#     668     if not np.all(np.isfinite([mn, mx])):
#     669         raise ValueError(
#
# ValueError: max must be larger than min in range parameter.
