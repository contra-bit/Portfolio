# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
# %matplotlib inline

# %%
start = datetime.date(2008, 1, 1)
end =  datetime.date(2018 ,1 , 1)
cstart= '1-1-2017'
cend = '2-9-2018'

# %%
from cryptocmd import CmcScraper

# Bitcoin
# initialise scraper
BTCscraper = CmcScraper('BTC', cstart, cend)
# Pandas dataFrame for the same data
BTC = BTCscraper.get_dataframe().set_index('Date')

# Ethereum
# initialise scraper
ETHscraper = CmcScraper('ETH', cstart, cend)
# Pandas dataFrame for the same data
ETH = ETHscraper.get_dataframe().set_index('Date')

# Ripple
# initialise scraper
XRPscraper = CmcScraper('XRP', cstart, cend)
# Pandas dataFrame for the same data
XRP = XRPscraper.get_dataframe().set_index('Date')

# Litecoin 
# initialise scraper
LTCscraper = CmcScraper('LTC', cstart, cend)
# Pandas dataFrame for the same data
LTC = LTCscraper.get_dataframe().set_index('Date')

# Neo 
# initialise scraper
NEOscraper = CmcScraper('NEO', cstart, cend)
# Pandas dataFrame for the same data
NEO = NEOscraper.get_dataframe().set_index('Date')

# Stellar
# initialise scraper
XLMscraper = CmcScraper('XLM', cstart, cend)
# Pandas dataFrame for the same data
XLM = XLMscraper.get_dataframe().set_index('Date')

# DASH
# initialise scraper
DASHscraper = CmcScraper('DASH', cstart, cend)
# Pandas dataFrame for the same data
DASH = DASHscraper.get_dataframe().set_index('Date')

# XMR
# initialise scraper
XMRscraper = CmcScraper('XMR', cstart, cend)
# Pandas dataFrame for the same data
XMR = XMRscraper.get_dataframe().set_index('Date')

# Ethereum Classic
# initialise scraper
ETCscraper = CmcScraper('ETC', cstart, cend)
# Pandas dataFrame for the same data
ETC = ETCscraper.get_dataframe().set_index('Date')

# Zcash
# initialise scraper
ZECscraper = CmcScraper('ZEC', cstart, cend)
# Pandas dataFrame for the same data
ZEC = ZECscraper.get_dataframe().set_index('Date')

# EOS
# initialise scraper
EOSscraper = CmcScraper('EOS', cstart, cend)
# Pandas dataFrame for the same data
EOS = EOSscraper.get_dataframe().set_index('Date')

# IOTA
# initialise scraper
MIOTAscraper = CmcScraper('MIOTA', cstart, cend)
# Pandas dataFrame for the same data
MIOTA = MIOTAscraper.get_dataframe().set_index('Date')

# Bitcoin Classic
# initialise scraper
BCHscraper = CmcScraper('BCH', cstart, cend)
# Pandas dataFrame for the same data
BCH = BCHscraper.get_dataframe().set_index('Date')

# Cardano
# initialise scraper
ADAscraper = CmcScraper('ADA', cstart, cend)
# Pandas dataFrame for the same data
ADA = ADAscraper.get_dataframe().set_index('Date')

print('done scrapping')
# Out:
# done scrapping

# %% [markdown]
# ** Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers**

# %%
tickers = ['BTC', 'ETH', 'XRP', 'BCH', 'ADA', 'LTC', 'NEO', 'XLM', 'EOS', 'MIOTA', 'DASH', 'XMR', 'ETC', 'ZEC']

# %% [markdown]
# ** Use pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks. Set the keys argument equal to the tickers list. Also pay attention to what axis you concatenate on.**

# %%
crypto_stocks = pd.concat([BTC, ETH, XRP, BCH, ADA, LTC, NEO, XLM, EOS, MIOTA, DASH, XMR, ETC, ZEC], axis=1, keys=tickers)

# %%
crypto_stocks.columns.names = ['Currency Ticker', 'Stock Info'] #Sets Columns Name

# %%
crypto_stocks.index.get_level_values('Date')
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10',
#                ...
#                '2018-06-01', '2018-06-02', '2018-07-01', '2018-07-02',
#                '2018-08-01', '2018-08-02', '2018-09-01', '2018-10-01',
#                '2018-11-01', '2018-12-01'],
#               dtype='datetime64[ns]', name='Date', length=404, freq=None)

# %%
crypto_stocks.sort_index(inplace=True)

# %%
crypto_stocks.head(10)
# Out:
# Currency Ticker      BTC                                                      \
# Stock Info          Open     High      Low    Close      Volume   Market Cap
# Date
# 2017-01-01        963.66  1003.08   958.70   998.33   147775000  15491200000
# 2017-01-02        970.94   989.11   970.74   989.02   150110000  15667900000
# 2017-01-03       1180.04  1222.50  1179.69  1222.50   229057000  19104800000
# 2017-01-04       1071.71  1091.72  1061.09  1080.50   289634000  17413000000
# 2017-01-05       1348.30  1434.32  1348.30  1421.60   713624000  21981800000
# 2017-01-06       2288.33  2448.39  2288.33  2407.88  1653180000  37446200000
# 2017-01-07       2492.60  2515.27  2419.23  2434.55   779914000  40928200000
# 2017-01-08       2871.30  2921.35  2685.61  2718.26  1324670000  47321800000
# 2017-01-09       4701.76  4892.01  4678.53  4892.01  2599080000  77748400000
# 2017-01-10       4341.05  4403.74  4269.81  4403.74  1208210000  72047300000
#
# ...

# %%
crypto_stocks.xs(key='Close',axis=1,level='Stock Info').mean()
# Out:
# Currency Ticker
# BTC      4786.890965
# ETH       303.859802
# XRP         0.344505
# BCH      1090.261891
# ADA         0.288769
# LTC        64.597351
# NEO        26.070284
# XLM         0.083420
# EOS         3.941058
# MIOTA       1.336465
# DASH      308.167995
# XMR       100.776832
# ETC        13.806733
# ZEC       225.314158
# dtype: float64

# %% [markdown]
# ** Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick+' Return'] = crypto_stocks[tick]['Close'].pct_change()
returns.head()
# Out:
#             BTC Return  ETH Return  XRP Return  BCH Return  ADA Return  \
# Date
# 2017-01-01         NaN         NaN         NaN         NaN         NaN
# 2017-01-02   -0.009326    0.313341    0.027010         NaN         NaN
# 2017-01-03    0.236072    0.616962   -0.173089         NaN         NaN
# 2017-01-04   -0.116155    1.922190    3.048077         NaN         NaN
# 2017-01-05    0.315687    0.504931    1.517586         NaN         NaN
#
#             LTC Return  NEO Return  XLM Return  EOS Return  MIOTA Return  \
# Date
# 2017-01-01         NaN         NaN         NaN         NaN           NaN
# 2017-01-02   -0.095344    0.037909   -0.049980         NaN           NaN
# 2017-01-03   -0.068627   -0.081654   -0.268562         NaN           NaN
# 2017-01-04    0.810526    0.516432    0.526102         NaN           NaN
# 2017-01-05    1.313953    0.555178    0.952870         NaN           NaN
#
#             DASH Return  XMR Return  ETC Return  ZEC Return
# Date
# ...

# %%
returns[0:5].head()
# Out:
#             BTC Return  ETH Return  XRP Return  BCH Return  ADA Return  \
# Date
# 2017-01-01         NaN         NaN         NaN         NaN         NaN
# 2017-01-02   -0.009326    0.313341    0.027010         NaN         NaN
# 2017-01-03    0.236072    0.616962   -0.173089         NaN         NaN
# 2017-01-04   -0.116155    1.922190    3.048077         NaN         NaN
# 2017-01-05    0.315687    0.504931    1.517586         NaN         NaN
#
#             LTC Return  NEO Return  XLM Return  EOS Return  MIOTA Return  \
# Date
# 2017-01-01         NaN         NaN         NaN         NaN           NaN
# 2017-01-02   -0.095344    0.037909   -0.049980         NaN           NaN
# 2017-01-03   -0.068627   -0.081654   -0.268562         NaN           NaN
# 2017-01-04    0.810526    0.516432    0.526102         NaN           NaN
# 2017-01-05    1.313953    0.555178    0.952870         NaN           NaN
#
#             DASH Return  XMR Return  ETC Return  ZEC Return
# Date
# ...

# %%
sns.pairplot(returns[1:5])

# %%
# Worst drop in a single day
returns.idxmin()
# Out:
# BTC Return     2017-01-13
# ETH Return     2017-01-13
# XRP Return     2017-09-01
# BCH Return     2017-05-08
# ADA Return     2017-06-10
# LTC Return     2017-02-13
# NEO Return     2017-02-13
# XLM Return     2017-02-13
# EOS Return     2017-10-13
# MIOTA Return   2017-07-13
# DASH Return    2017-12-01
# XMR Return     2017-01-13
# ETC Return     2017-02-13
# ZEC Return     2017-02-13
# dtype: datetime64[ns]

# %%
sns.distplot(returns.ix['2017-01-01':'2018-02-02']['BTC Return'],color='red', bins=100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-150-58f625ed4c7c> in <module>()
# ----> 1 sns.distplot(returns.ix['2017-01-01':'2018-02-02']['BTC Return'][:10],color='red', bins=100)
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     212         hist_color = hist_kws.pop("color", color)
#     213         ax.hist(a, bins, orientation=orientation,
# --> 214                 color=hist_color, **hist_kws)
#     215         if hist_color != color:
#     216             hist_kws["color"] = hist_color
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
# ...
